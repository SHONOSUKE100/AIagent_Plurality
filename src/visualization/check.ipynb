# %%
import sqlite3

# %%
con = sqlite3.connect("../../data/twitter_simulation.db")

# %%
cur = con.cursor()

# %%
# 1. テーブル一覧を取得
cur.execute("SELECT name FROM sqlite_master WHERE type='table'")
tables = cur.fetchall()

# 2. 結果を表示
print("データベース内のテーブル一覧:")
for table_name, in tables:
    print(f"- {table_name}")
# Out:
# データベース内のテーブル一覧:
# - user
# - sqlite_sequence
# - post
# - follow
# - mute
# - like
# - dislike
# - report
# - trace
# - rec
# - comment
# - comment_like
# - comment_dislike
# - product
# - chat_group
# - group_members
# - group_messages

# %%
if not tables:
    print("\nテーブルが見つかりませんでした。")
else:
    for table_name, in tables:
        print(f"\n=== テーブル: {table_name} ===")

        schema_rows = cur.execute(f"PRAGMA table_info('{table_name}')").fetchall()
        column_names = [column_info[1] for column_info in schema_rows]
        print("カラム一覧:")
        for cid, name, col_type, notnull, default, pk in schema_rows:
            print(f"  - {name} ({col_type}) NOT NULL={bool(notnull)} PK={'Yes' if pk else 'No'}")

        row_count = cur.execute(f"SELECT COUNT(*) FROM '{table_name}'").fetchone()[0]
        print(f"レコード件数: {row_count}")

        sample_rows = cur.execute(f"SELECT * FROM '{table_name}' LIMIT 5").fetchall()
        if sample_rows:
            print("サンプル (先頭5件):")
            print("  | ".join(column_names))
            for sample in sample_rows:
                formatted = [str(value) for value in sample]
                print("  | ".join(formatted))
        else:
            print("サンプル (先頭5件): データなし")
# Out:
# === テーブル: user ===
# カラム一覧:
#   - user_id (INTEGER) NOT NULL=False PK=Yes
#   - agent_id (INTEGER) NOT NULL=False PK=No
#   - user_name (TEXT) NOT NULL=False PK=No
#   - name (TEXT) NOT NULL=False PK=No
#   - bio (TEXT) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
#   - num_followings (INTEGER) NOT NULL=False PK=No
#   - num_followers (INTEGER) NOT NULL=False PK=No
# レコード件数: 100
# サンプル (先頭5件):
# user_id  | agent_id  | user_name  | name  | bio  | created_at  | num_followings  | num_followers
# 0  | 0  | user_8565  | user_8565  | 51歳の会社員として働いています。趣味は楽器演奏で、休日はスノーボードを楽しんでいます。  | 0  | 0  | 0
# 1  | 1  | user_2803  | user_2803  | 仙台在住の教師。イラストとスキーが好きです。  | 0  | 0  | 0
# 2  | 2  | user_5057  | user_5057  | 奈良在住のコンサルタント。ショッピングと書道が好きです。  | 0  | 0  | 0
# 3  | 3  | user_7209  | user_7209  | 熊本在住。美容師として活動中。書道が趣味で、最近はスキーにもハマっています。  | 0  | 0  | 0
# 4  | 4  | user_3300  | user_3300  | 相模原在住の営業職。ダンスとサイクリングが好きです。  | 0  | 0  | 0
#
# === テーブル: sqlite_sequence ===
# カラム一覧:
#   - name () NOT NULL=False PK=No
#   - seq () NOT NULL=False PK=No
# レコード件数: 4
# サンプル (先頭5件):
# name  | seq
# user  | 99
# post  | 20
# like  | 195
# comment  | 173
#
# === テーブル: post ===
# カラム一覧:
#   - post_id (INTEGER) NOT NULL=False PK=Yes
#   - user_id (INTEGER) NOT NULL=False PK=No
#   - original_post_id (INTEGER) NOT NULL=False PK=No
#   - content (TEXT) NOT NULL=False PK=No
#   - quote_content (TEXT) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
#   - num_likes (INTEGER) NOT NULL=False PK=No
#   - num_dislikes (INTEGER) NOT NULL=False PK=No
#   - num_shares (INTEGER) NOT NULL=False PK=No
#   - num_reports (INTEGER) NOT NULL=False PK=No
# レコード件数: 20
# サンプル (先頭5件):
# post_id  | user_id  | original_post_id  | content  | quote_content  | created_at  | num_likes  | num_dislikes  | num_shares  | num_reports
# 1  | 17  | None  | user_9867 is joining the simulation!  | None  | 0  | 0  | 0  | 0  | 0
# 2  | 6  | None  | user_4326 is joining the simulation!  | None  | 0  | 0  | 0  | 0  | 0
# 3  | 12  | None  | user_1518 is joining the simulation!  | None  | 0  | 0  | 0  | 0  | 0
# 4  | 32  | None  | user_4313 is joining the simulation!  | None  | 0  | 0  | 0  | 0  | 0
# 5  | 29  | None  | user_340 is joining the simulation!  | None  | 0  | 0  | 0  | 0  | 0
#
# === テーブル: follow ===
# カラム一覧:
#   - follow_id (INTEGER) NOT NULL=False PK=Yes
#   - follower_id (INTEGER) NOT NULL=False PK=No
#   - followee_id (INTEGER) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
#
# === テーブル: mute ===
# カラム一覧:
#   - mute_id (INTEGER) NOT NULL=False PK=Yes
#   - muter_id (INTEGER) NOT NULL=False PK=No
#   - mutee_id (INTEGER) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
#
# === テーブル: like ===
# カラム一覧:
#   - like_id (INTEGER) NOT NULL=False PK=Yes
#   - user_id (INTEGER) NOT NULL=False PK=No
#   - post_id (INTEGER) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 195
# サンプル (先頭5件):
# like_id  | user_id  | post_id  | created_at
# 1  | 27  | 10  | 1
# 2  | 86  | 10  | 1
# 3  | 4  | 10  | 1
# 4  | 68  | 10  | 1
# 5  | 27  | 12  | 1
#
# === テーブル: dislike ===
# カラム一覧:
#   - dislike_id (INTEGER) NOT NULL=False PK=Yes
#   - user_id (INTEGER) NOT NULL=False PK=No
#   - post_id (INTEGER) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
#
# === テーブル: report ===
# カラム一覧:
#   - report_id (INTEGER) NOT NULL=False PK=Yes
#   - user_id (INTEGER) NOT NULL=False PK=No
#   - post_id (INTEGER) NOT NULL=False PK=No
#   - report_reason (TEXT) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
#
# === テーブル: trace ===
# カラム一覧:
#   - user_id (INTEGER) NOT NULL=False PK=Yes
#   - created_at (DATETIME) NOT NULL=False PK=Yes
#   - action (TEXT) NOT NULL=False PK=Yes
#   - info (TEXT) NOT NULL=False PK=Yes
# レコード件数: 588
# サンプル (先頭5件):
# user_id  | created_at  | action  | info
# 0  | 0  | sign_up  | {"name": "user_8565", "user_name": "user_8565", "bio": "51\u6b73\u306e\u4f1a\u793e\u54e1\u3068\u3057\u3066\u50cd\u3044\u3066\u3044\u307e\u3059\u3002\u8da3\u5473\u306f\u697d\u5668\u6f14\u594f\u3067\u3001\u4f11\u65e5\u306f\u30b9\u30ce\u30fc\u30dc\u30fc\u30c9\u3092\u697d\u3057\u3093\u3067\u3044\u307e\u3059\u3002"}
# 1  | 0  | sign_up  | {"name": "user_2803", "user_name": "user_2803", "bio": "\u4ed9\u53f0\u5728\u4f4f\u306e\u6559\u5e2b\u3002\u30a4\u30e9\u30b9\u30c8\u3068\u30b9\u30ad\u30fc\u304c\u597d\u304d\u3067\u3059\u3002"}
# 2  | 0  | sign_up  | {"name": "user_5057", "user_name": "user_5057", "bio": "\u5948\u826f\u5728\u4f4f\u306e\u30b3\u30f3\u30b5\u30eb\u30bf\u30f3\u30c8\u3002\u30b7\u30e7\u30c3\u30d4\u30f3\u30b0\u3068\u66f8\u9053\u304c\u597d\u304d\u3067\u3059\u3002"}
# 3  | 0  | sign_up  | {"name": "user_7209", "user_name": "user_7209", "bio": "\u718a\u672c\u5728\u4f4f\u3002\u7f8e\u5bb9\u5e2b\u3068\u3057\u3066\u6d3b\u52d5\u4e2d\u3002\u66f8\u9053\u304c\u8da3\u5473\u3067\u3001\u6700\u8fd1\u306f\u30b9\u30ad\u30fc\u306b\u3082\u30cf\u30de\u3063\u3066\u3044\u307e\u3059\u3002"}
# 4  | 0  | sign_up  | {"name": "user_3300", "user_name": "user_3300", "bio": "\u76f8\u6a21\u539f\u5728\u4f4f\u306e\u55b6\u696d\u8077\u3002\u30c0\u30f3\u30b9\u3068\u30b5\u30a4\u30af\u30ea\u30f3\u30b0\u304c\u597d\u304d\u3067\u3059\u3002"}
#
# === テーブル: rec ===
# カラム一覧:
#   - user_id (INTEGER) NOT NULL=False PK=Yes
#   - post_id (INTEGER) NOT NULL=False PK=Yes
# レコード件数: 200
# サンプル (先頭5件):
# user_id  | post_id
# 0  | 10
# 0  | 12
# 1  | 10
# 1  | 12
# 2  | 10
#
# === テーブル: comment ===
# カラム一覧:
#   - comment_id (INTEGER) NOT NULL=False PK=Yes
#   - post_id (INTEGER) NOT NULL=False PK=No
#   - user_id (INTEGER) NOT NULL=False PK=No
#   - content (TEXT) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
#   - num_likes (INTEGER) NOT NULL=False PK=No
#   - num_dislikes (INTEGER) NOT NULL=False PK=No
# レコード件数: 173
# サンプル (先頭5件):
# comment_id  | post_id  | user_id  | content  | created_at  | num_likes  | num_dislikes
# 1  | 12  | 97  | Welcome to the simulation, user_6238! Excited to have you here.  | 1  | 0  | 0
# 2  | 12  | 20  | Welcome to the simulation, user_6238! Excited to see what you'll bring to the table.  | 1  | 0  | 0
# 3  | 10  | 17  | Welcome to the simulation, user_1952!  | 1  | 0  | 0
# 4  | 12  | 56  | Welcome to the simulation, user_6238! Excited to see what you'll bring to the table.  | 1  | 0  | 0
# 5  | 12  | 46  | Welcome to the simulation, user_6238! Excited to see what you'll bring to the table.  | 1  | 0  | 0
#
# === テーブル: comment_like ===
# カラム一覧:
#   - comment_like_id (INTEGER) NOT NULL=False PK=Yes
#   - user_id (INTEGER) NOT NULL=False PK=No
#   - comment_id (INTEGER) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
#
# === テーブル: comment_dislike ===
# カラム一覧:
#   - comment_dislike_id (INTEGER) NOT NULL=False PK=Yes
#   - user_id (INTEGER) NOT NULL=False PK=No
#   - comment_id (INTEGER) NOT NULL=False PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
#
# === テーブル: product ===
# カラム一覧:
#   - product_id (INTEGER) NOT NULL=False PK=Yes
#   - product_name (TEXT) NOT NULL=False PK=No
#   - sales (INTEGER) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
#
# === テーブル: chat_group ===
# カラム一覧:
#   - group_id (INTEGER) NOT NULL=False PK=Yes
#   - name (TEXT) NOT NULL=True PK=No
#   - created_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
#
# === テーブル: group_members ===
# カラム一覧:
#   - group_id (INTEGER) NOT NULL=True PK=Yes
#   - agent_id (INTEGER) NOT NULL=True PK=Yes
#   - joined_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
#
# === テーブル: group_messages ===
# カラム一覧:
#   - message_id (INTEGER) NOT NULL=False PK=Yes
#   - group_id (INTEGER) NOT NULL=True PK=No
#   - sender_id (INTEGER) NOT NULL=True PK=No
#   - content (TEXT) NOT NULL=True PK=No
#   - sent_at (DATETIME) NOT NULL=False PK=No
# レコード件数: 0
# サンプル (先頭5件): データなし
